# %% [markdown]
# # Applied Data Science Capstone - Week 4 Project Introduction
#
# - In this project, I will help people who are looking for a rental properties in bangkok for the best suitable location.
# - They will be able to see the price per square meter so they can decide accoding to their budgets.
# - They can decide whether to live in restidential or commercial area.
# - They will be able to see what is the average rental price in Bangkok, Thailand.

# %% [markdown]
# ## Data
# - The data was got from https://www.thailand-property.com/properties-for-rent/bangkok?page=1
# - Using beautifulsoup to scrap the data from the website.
# - Coordinate location of each location in Bangkok from csv file which I got from some online website.
# - foursqure data for the near by interesting places near by in each location

# %% [markdown]
# ## First I use beautifulsoup to scrap the data from the rental properties website as below
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Methodology
#
# - I checked the data set for each location about the bed_rooms, bath_rooms, size, and price.
# - After theat removing the outlier from price and plot the scatter plot chart between rooms and price.

# %% [markdown]
# ## I made some visualization to understand the data
#
# ![image.png](attachment:image.png)
#
#
# ## This scatter plot is plottet before remove the outliers
# ![image-2.png](attachment:image-2.png)
#
# ## And this after remove outliers
# ![image-5.png](attachment:image-5.png)
#
#
# ![image-3.png](attachment:image-3.png)
#
# ## the areas which have the highest price are Patum Wan, Watthana, Bang Rak, and Sathorn
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Then I combine coornidate location that i got from internet to the dataframe and i ran foursqaure to get the interesting place near by all the location
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Next I ran the k-mean clustering model to separate the area into 2 areas - comercial and residential area
#
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Result
#
# - Fianlly, base on this information the stakeholder will be able to see which area is most suaitable for then in term of price, interesting places, whether they will live in industial or commercial areas.
# - Based fomr the last picture, we can see that the red point are the comercial area which have higher rental price while the blue one are residential area which are less expensive.
